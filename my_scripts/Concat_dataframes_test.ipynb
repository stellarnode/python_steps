# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sbn
from datetime import datetime

# %%
transactions_1 = pd.read_excel('/Users/stellarnode/Desktop/1.xlsx')

# %%
transactions_2 = pd.read_excel('/Users/stellarnode/Desktop/2.xlsx')

# %%
transactions_1
# Out:
#                        Номер заказа                 Дата         IP-адрес  \
# 0  bRp8onGoGf4PX4j35D7YSji88WrvFAUf  2020.01.30 03:30:06  213.108.129.237
# 1  3N86xJYmfYJezSdUzMU4wT7ETxjnWMdq  2020.01.29 17:21:22     81.27.52.241
#
#       Уникальный номер заказа в системе Состояние  Описание заказа  Сумма  \
# 0  bcc32c90-a805-7232-aaa2-8fae0007a120  Завершён            49849   4990
# 1  788b46cb-c33a-77a9-a5ef-73fb0007a120  Завершён            49848   4000
#
#    ECI ipCountry  Код ответа процессинга  ... Auth code Reference number  \
# 0    7    Россия                       0  ...         0       3089987193
# 1    5    Россия                       0  ...         2       2989983760
#
#    authRefNum  Терминал  Процессинг  3DSec/SSL Идентификатор клиента  \
# 0  3089987193  28000001    28000001        NaN                   NaN
# 1  2989983760  28000001    28000001    3DS_enr                   NaN
#
#                    Email клиента  AFT/OCT  \
# ...

# %%
transactions_2
# Out:
#                        Номер заказа                 Дата         IP-адрес  \
# 0  budlXnoO246wYH4bi6PEfbiE4PnmGC0h  2020.01.29 16:32:10  213.108.129.237
# 1  onXq2trVUqOs0rpyckkJ35lJFh3DxCWM  2020.01.29 16:31:54              NaN
# 2  qXjBsFxEe763iUOPXVi11d55TK9IuNbv  2020.01.29 16:20:28              NaN
#
#       Уникальный номер заказа в системе Состояние  Описание заказа  Сумма  \
# 0  bfe895e7-494a-79ec-ab7e-2b6c0007a120  Завершён            49847   8990
# 1  625c7b4f-4e0f-7a4e-b694-66540007a120  Отклонён            49846   8990
# 2  4bb13efb-4ecc-7c18-8daf-80b80007a120  Отклонён            49845   8990
#
#    ECI  ipCountry  Код ответа процессинга  ... Auth code Reference number  \
# 0    7     Россия                       0  ...         0     2.989983e+09
# 1    7  <Unknown>                   -2007  ...         2              NaN
# 2    7  <Unknown>                   -2007  ...         2              NaN
#
# ...

# %%
all = transactions_1.append(transactions_2)

# %%
all
# Out:
#                        Номер заказа                 Дата         IP-адрес  \
# 0  bRp8onGoGf4PX4j35D7YSji88WrvFAUf  2020.01.30 03:30:06  213.108.129.237
# 1  3N86xJYmfYJezSdUzMU4wT7ETxjnWMdq  2020.01.29 17:21:22     81.27.52.241
# 0  budlXnoO246wYH4bi6PEfbiE4PnmGC0h  2020.01.29 16:32:10  213.108.129.237
# 1  onXq2trVUqOs0rpyckkJ35lJFh3DxCWM  2020.01.29 16:31:54              NaN
# 2  qXjBsFxEe763iUOPXVi11d55TK9IuNbv  2020.01.29 16:20:28              NaN
#
#       Уникальный номер заказа в системе Состояние  Описание заказа  Сумма  \
# 0  bcc32c90-a805-7232-aaa2-8fae0007a120  Завершён            49849   4990
# 1  788b46cb-c33a-77a9-a5ef-73fb0007a120  Завершён            49848   4000
# 0  bfe895e7-494a-79ec-ab7e-2b6c0007a120  Завершён            49847   8990
# 1  625c7b4f-4e0f-7a4e-b694-66540007a120  Отклонён            49846   8990
# 2  4bb13efb-4ecc-7c18-8daf-80b80007a120  Отклонён            49845   8990
#
# ...
