# %%
import os

# %%
files_path = '/Volumes/Magic Power/(V) Videos & Movies/TV-SERIES/Shani Dev (2016)/Season 01'

# %%
file_list = os.listdir(files_path)
file_list
# Out:
# ['Shani Dev Rus 001.mp4',
#  'Shani Dev Rus 002.mp4',
#  'Shani Dev Rus 003.mp4',
#  'Shani Dev Rus 004.mp4',
#  'Shani Dev Rus 005.mp4',
#  'Shani Dev Rus 006.mp4',
#  'Shani Dev Rus 007.mp4',
#  'Shani Dev Rus 008.mp4',
#  'Shani Dev Rus 009.mp4',
#  'Shani Dev Rus 010.mp4',
#  'Shani Dev Rus 011.mp4',
#  'Shani Dev Rus 012.mp4',
#  'Shani Dev Rus 013.mp4',
#  'Shani Dev Rus 014.mp4',
#  'Shani Dev Rus 015.mp4',
#  'Shani Dev Rus 016.mp4',
#  'Shani Dev Rus 017.mp4',
#  'Shani Dev Rus 018.mp4',
#  'Shani Dev Rus 019.mp4',
#  'Shani Dev Rus 020.mp4',
#  'Shani Dev Rus 021.mp4',
#  'Shani Dev Rus 022.mp4',
#  'Shani Dev Rus 023.mp4',
#  'Shani Dev Rus 024.mp4',
#  'Shani Dev Rus 025.mp4',
#  'Shani Dev Rus 026.mp4',
#  'Shani Dev Rus 027.mp4',
#  'Shani Dev Rus 028.mp4',
#  'Shani Dev Rus 029.mp4',
#  'Shani Dev Rus 030.mp4',
#  'Shani Dev Rus 031.mp4',
#  'Shani Dev Rus 032.mp4',
#  'Shani Dev Rus 033.mp4',
#  'Shani Dev Rus 034.mp4',
#  'Shani Dev Rus 035.mp4',
# ...

# %%
def add_zeroes(number):
    out = str(number)
    prefix = ''
    if number < 10:
        prefix = '00'
    elif number < 100:
        prefix = '0'
    else:
        prefix = ''
    return prefix + out

# %%
for count, filename in enumerate(file_list):
    full_path = os.path.join(files_path, filename)
    print(full_path)
    if os.path.isfile(full_path):
        name = full_path.split('.')
        dest = name[0][:-4] + '_s01e' + add_zeroes(count + 1) + '.' + name[1]
        print(dest)
        os.rename(full_path, dest)
# Out:
# /Volumes/Magic Power/(V) Videos & Movies/TV-SERIES/Shani Dev (2016)/Season 01/Shani Dev Rus 001.mp4
# /Volumes/Magic Power/(V) Videos & Movies/TV-SERIES/Shani Dev (2016)/Season 01/Shani Dev Rus_s01e001.mp4
# /Volumes/Magic Power/(V) Videos & Movies/TV-SERIES/Shani Dev (2016)/Season 01/Shani Dev Rus 002.mp4
# /Volumes/Magic Power/(V) Videos & Movies/TV-SERIES/Shani Dev (2016)/Season 01/Shani Dev Rus_s01e002.mp4
# /Volumes/Magic Power/(V) Videos & Movies/TV-SERIES/Shani Dev (2016)/Season 01/Shani Dev Rus 003.mp4
# /Volumes/Magic Power/(V) Videos & Movies/TV-SERIES/Shani Dev (2016)/Season 01/Shani Dev Rus_s01e003.mp4
# /Volumes/Magic Power/(V) Videos & Movies/TV-SERIES/Shani Dev (2016)/Season 01/Shani Dev Rus 004.mp4
# /Volumes/Magic Power/(V) Videos & Movies/TV-SERIES/Shani Dev (2016)/Season 01/Shani Dev Rus_s01e004.mp4
# /Volumes/Magic Power/(V) Videos & Movies/TV-SERIES/Shani Dev (2016)/Season 01/Shani Dev Rus 005.mp4
# ...
